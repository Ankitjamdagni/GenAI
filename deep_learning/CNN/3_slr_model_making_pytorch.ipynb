# %% [markdown]
# # MachineLearning is all about
# 1. Getting data converted to numerical representation.
# 2. Building a model to learn pattern from numerical data made in step 1.

# %%
import torch

# %% [markdown]
# ## step1: Create/load sample dataset

# %%
# y=mx+c
# y=dependent variable, x=independent variable, m=weight, c=bias

# assumed variables
weight = 0.7 # m
bias = 0.3 # c

# let's create a dataset
X = torch.arange(0,1,0.02).unsqueeze(dim=1) # add extra dimension
y = weight*X + bias
X[:5], y[:5], X.shape, y.shape
# Out:
# (tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800]]),
#  tensor([[0.3000],
#          [0.3140],
#          [0.3280],
#          [0.3420],
#          [0.3560]]),
#  torch.Size([50, 1]),
#  torch.Size([50, 1]))

# %%
y_test
# Out:
# tensor([[0.8600],
#         [0.8740],
#         [0.8880],
#         [0.9020],
#         [0.9160],
#         [0.9300],
#         [0.9440],
#         [0.9580],
#         [0.9720],
#         [0.9860]])

# %% [markdown]
# ## step2: creat train & test data set

# %%
splitter = int(0.8*len(X))
splitter
# Out:
# 40

# %%
x_train, y_train = X[:splitter], y[:splitter]
x_test, y_test = X[splitter:], y[splitter:]
x_train.shape
# Out:
# torch.Size([40, 1])

# %% [markdown]
# ## step3: visualize data

# %%
import matplotlib.pyplot as plt

plt.scatter(x_train, y_train, c='b', s=4)
plt.scatter(x_test, y_test, c='g', s=4)

# %% [markdown]
# ## step4: build model

# %%
import torch
from torch import nn

# %% [markdown]
# #### What our model does:
# 1. `Start with random values, i.e., weights and bias.`
# 2. `Look at training data and adjust the random values to become a better representation of data.`
#
# #### How it do so:
# 1. `Gradient descent.`
# 2. `Back Propagation.`

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.weights = nn.Parameter(torch.randn(1, requires_grad=True, dtype=torch.float))
        self.bias = nn.Parameter(torch.randn(1, requires_grad=True, dtype=torch.float))
        
    def forward(self,x:torch.tensor) -> torch.tensor:
        return self.weights * x + self.bias

# %% [markdown]
# ## model building essentials
# #### torch.nn (all building blocks here to make a graph)
# #### torch.nn.parameters (what parameters should a model try and learn)
# #### torch.nn.module (base class for all neural network models, including custom-made) | always overwrite the forward method
# #### torch.optim (optimizers of PyTorch help in gradient descent)
# #### def forward (defines what happens in forward computation)

# %% [markdown]
# ## step5:check content of pytorch model

# %%
# create a random seed
ranadom_seed = 42
torch.manual_seed(ranadom_seed)

# create instance of class
model0 = LinearRegressionModel()
model0
# Out:
# LinearRegressionModel()

# %%
list(model0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %%
model0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.3367])), ('bias', tensor([0.1288]))])

# %% [markdown]
# # aim is to make these weights=0.3367 and biases =0.1288 from the model to move values towards our assumed initial values, i.e., weight = 0.7, bias = 0.3

# %%
# simple mode
y_preds_simple_mode = model0(x_test)
y_preds_simple_mode
# Out:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]], grad_fn=<AddBackward0>)

# %%
# inference mode
with torch.inference_mode():
    y_preds = model0(x_test)
    

y_preds
# Out:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]])

# %% [markdown]
# ## plotting predictions

# %%
plt.scatter(x_train,y_train, c='b', s=10, label=' Train Data')
plt.scatter(x_test,y_test, c='g', s=10, label=' Test Data')
plt.scatter(x_test,y_preds, c='r', s=40, label=' Predictions by inference mode')
plt.scatter(x_test.numpy(),y_preds_simple_mode.detach(), c='black', s=15, label=' Predictions by simple mode')
plt.legend(   frameon=True, title="Legend", fontsize=8,)

# %% [markdown]
# # Actual Training (From unknown random params to known params)
#
# `REQUIREMENTS:`
# * Loss function
# * Optimizer
# * TRAINING LOOP
# * TESTING LOOP
#
# `EXPLANATION`
# 1. Need a LOSS FUNCTION / LOSS FUNCTION/ CRITERION (all are the same)to measure how poorly our model is performing OR loss function measures how wrong our model's parameters are (weights, bias)
# 2. Need an OPTIMIZER, which takes into account the loss in each iteration / Epoch and adjusts the parameters.

# %% [markdown]
# #### step0: List no fo parameters to be trained

# %%
list(model0.parameters()), model0.state_dict()
# Out:
# ([Parameter containing:
#   tensor([0.3367], requires_grad=True),
#   Parameter containing:
#   tensor([0.1288], requires_grad=True)],
#  OrderedDict([('weights', tensor([0.3367])), ('bias', tensor([0.1288]))]))

# %% [markdown]
# #### step1: choose the loss function and the optimizer.

# %%
# loss function choosing
loss_fn = nn.L1Loss()

# optimizer function choosing
optimizer_fn = torch.optim.SGD(params=model0.parameters(), lr=0.01, )

# %% [markdown]
# # Easter egg
# #### e.g., our parameter is [weights = 0.3367] having 4 digits after decimal
# #### if lr=0.0001, the optimizer starts changing the last digit, i.e., 7 of the weight(parameter), which means the change is quite small
# #### if lr=0.001, optimizer starts changing the last second digit, i.e., 6 of the weight(parameter), which means the change is quite small, but greater than lr=0.0001
# #### If I want to change the digit next to the decimal, i.e., 3, I must choose lr=0.1

# %% [markdown]
# #### Q: Which loss function and optimizer should I use?
# #### A: Have patience, practicing different datasets and the nature of data will teach what to use when
# ####  e.g. 1. In a regression problem, we can use loss_fn=Li loss function(MAE) and optimizer=SGD
# ####       2. For a classification problem, we can use the BinaryCrossEntropy loss function

# %% [markdown]
# #### step2: make the training loop
# * loop through the data.
# * Forward pass (it involves data moving through the model's forward() function/functions). | make predictions on data | forward propagation
# * Calculate the loss (compare forward pass predictions to ground truth labels)
# * Optimize Zero Grad (will discuss later)
# * **Back propagation:** Loss Backward | move backward through the network to calculate the gradient of each of the parameters of our model W.R.T the loss
# * **gradient descent:** Adjust our model's parameters to minimize the loss | (optimizers). | chnage in slope and intercept in our case.

# %% [markdown]
# #### step3: set epoches

# %%
# set no of loops | a Hyperparameter
epoches = 100

# %%
# training loop
for epoch in range(epoches):
    # 0. TRAINING | PUT MODEL IN TRAINING MODE
    model0.train() 
    
    # 1. Setup forward pass | FORWARD PASS TRAINING DATA USING FORWARD() METHOD INSIDE MODEL OBJECT
    y_pred_learned = model0(x_train)
    
    # 2. Calculate the loss values | only calculations, nothing more | TRAINING LOSS
    loss = loss_fn(y_pred_learned, y_train) # input first target next
    print(loss)
    
    # 3. Optimizer zero grad | Prevents Gradient Accumulation after each loop & Memory Management
    optimizer_fn.zero_grad()
    
    # 4. Perform back propagation w.r.t paramaeters of the model
    loss.backward() # compute gradient of every parameter with require_grad = true | check minima(convergence point) is achieved or not
    
    # 5. Setup Optimizer | make a calculation of how to change the parameters w.r.t back propagation of loss
    optimizer_fn.step() # by default, how the optimizer changes(values) will accumulate through the loop, so we have to zero them above via step 3.

    # TESTING/Evaluation | loop can be put under running conditions like run after every 10 epoch. 
    # model0.eval()  # turn off different settings not needed in testing  mode, like gradient tracking, dropout, and batch normalization
    # with torch.inference_mode():
    #     y_preds_100 = model0(x_test)
    #     loss can be calculated here | and that will be called TESTING LOSS
    # print statements to be printed after each epoch

    print(f"\n actual weight and bias must be: {weight,bias} \n randomly initialized weight and bias are: 0.3367,0.1288 \n weights and biases after {epoches} are {model0.state_dict()}")
# Out:
# tensor(0.3129, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3406])), ('bias', tensor([0.1388]))])
# tensor(0.3014, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3445])), ('bias', tensor([0.1488]))])
# tensor(0.2898, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3484])), ('bias', tensor([0.1588]))])
# tensor(0.2783, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3523])), ('bias', tensor([0.1688]))])
# tensor(0.2668, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3562])), ('bias', tensor([0.1788]))])
# tensor(0.2553, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3601])), ('bias', tensor([0.1888]))])
# tensor(0.2438, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3640])), ('bias', tensor([0.1988]))])
# tensor(0.2322, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3679])), ('bias', tensor([0.2088]))])
# tensor(0.2207, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3718])), ('bias', tensor([0.2188]))])
# tensor(0.2092, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3757])), ('bias', tensor([0.2288]))])
# tensor(0.1977, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3796])), ('bias', tensor([0.2388]))])
# tensor(0.1862, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3835])), ('bias', tensor([0.2488]))])
# tensor(0.1746, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3874])), ('bias', tensor([0.2588]))])
# tensor(0.1631, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3913])), ('bias', tensor([0.2688]))])
# tensor(0.1516, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3952])), ('bias', tensor([0.2788]))])
# tensor(0.1401, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.3991])), ('bias', tensor([0.2888]))])
# tensor(0.1285, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4030])), ('bias', tensor([0.2988]))])
# tensor(0.1170, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4069])), ('bias', tensor([0.3088]))])
# tensor(0.1061, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4108])), ('bias', tensor([0.3178]))])
# tensor(0.0968, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4146])), ('bias', tensor([0.3258]))])
# tensor(0.0891, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4184])), ('bias', tensor([0.3333]))])
# tensor(0.0823, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4222])), ('bias', tensor([0.3403]))])
# tensor(0.0764, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4258])), ('bias', tensor([0.3463]))])
# tensor(0.0716, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4293])), ('bias', tensor([0.3518]))])
# tensor(0.0675, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4328])), ('bias', tensor([0.3568]))])
# tensor(0.0640, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4361])), ('bias', tensor([0.3613]))])
# tensor(0.0610, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4394])), ('bias', tensor([0.3653]))])
# tensor(0.0585, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4425])), ('bias', tensor([0.3688]))])
# tensor(0.0564, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4455])), ('bias', tensor([0.3718]))])
# tensor(0.0546, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4483])), ('bias', tensor([0.3743]))])
# tensor(0.0531, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4512])), ('bias', tensor([0.3768]))])
# tensor(0.0518, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4539])), ('bias', tensor([0.3788]))])
# tensor(0.0507, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4564])), ('bias', tensor([0.3803]))])
# tensor(0.0498, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4590])), ('bias', tensor([0.3818]))])
# tensor(0.0490, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4615])), ('bias', tensor([0.3833]))])
# tensor(0.0482, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4639])), ('bias', tensor([0.3843]))])
# tensor(0.0475, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4662])), ('bias', tensor([0.3853]))])
# tensor(0.0469, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4684])), ('bias', tensor([0.3858]))])
# tensor(0.0464, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4706])), ('bias', tensor([0.3863]))])
# tensor(0.0459, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4728])), ('bias', tensor([0.3868]))])
# tensor(0.0454, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4748])), ('bias', tensor([0.3868]))])
# tensor(0.0450, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4768])), ('bias', tensor([0.3868]))])
# tensor(0.0446, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4788])), ('bias', tensor([0.3868]))])
# tensor(0.0442, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4808])), ('bias', tensor([0.3868]))])
# tensor(0.0438, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4828])), ('bias', tensor([0.3868]))])
# tensor(0.0434, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4848])), ('bias', tensor([0.3868]))])
# tensor(0.0431, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4866])), ('bias', tensor([0.3863]))])
# tensor(0.0427, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4884])), ('bias', tensor([0.3858]))])
# tensor(0.0424, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4902])), ('bias', tensor([0.3853]))])
# tensor(0.0420, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4920])), ('bias', tensor([0.3848]))])
# tensor(0.0417, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4938])), ('bias', tensor([0.3843]))])
# tensor(0.0413, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4956])), ('bias', tensor([0.3838]))])
# tensor(0.0410, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4974])), ('bias', tensor([0.3833]))])
# tensor(0.0406, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.4992])), ('bias', tensor([0.3828]))])
# tensor(0.0403, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5010])), ('bias', tensor([0.3823]))])
# tensor(0.0399, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5028])), ('bias', tensor([0.3818]))])
# tensor(0.0396, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5046])), ('bias', tensor([0.3813]))])
# tensor(0.0392, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5064])), ('bias', tensor([0.3808]))])
# tensor(0.0389, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5082])), ('bias', tensor([0.3803]))])
# tensor(0.0385, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5100])), ('bias', tensor([0.3798]))])
# tensor(0.0382, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5116])), ('bias', tensor([0.3788]))])
# tensor(0.0379, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5134])), ('bias', tensor([0.3783]))])
# tensor(0.0375, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5152])), ('bias', tensor([0.3778]))])
# tensor(0.0372, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5168])), ('bias', tensor([0.3768]))])
# tensor(0.0368, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5186])), ('bias', tensor([0.3763]))])
# tensor(0.0365, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5202])), ('bias', tensor([0.3753]))])
# tensor(0.0361, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5220])), ('bias', tensor([0.3748]))])
# tensor(0.0358, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5236])), ('bias', tensor([0.3738]))])
# tensor(0.0354, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5254])), ('bias', tensor([0.3733]))])
# tensor(0.0351, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5272])), ('bias', tensor([0.3728]))])
# tensor(0.0348, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5288])), ('bias', tensor([0.3718]))])
# tensor(0.0344, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5306])), ('bias', tensor([0.3713]))])
# tensor(0.0341, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5322])), ('bias', tensor([0.3703]))])
# tensor(0.0337, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5340])), ('bias', tensor([0.3698]))])
# tensor(0.0334, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5355])), ('bias', tensor([0.3688]))])
# tensor(0.0330, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5373])), ('bias', tensor([0.3683]))])
# tensor(0.0327, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5391])), ('bias', tensor([0.3678]))])
# tensor(0.0324, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5407])), ('bias', tensor([0.3668]))])
# tensor(0.0320, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5425])), ('bias', tensor([0.3663]))])
# tensor(0.0317, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5441])), ('bias', tensor([0.3653]))])
# tensor(0.0313, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5459])), ('bias', tensor([0.3648]))])
# tensor(0.0310, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5475])), ('bias', tensor([0.3638]))])
# tensor(0.0306, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5493])), ('bias', tensor([0.3633]))])
# tensor(0.0303, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5509])), ('bias', tensor([0.3623]))])
# tensor(0.0300, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5527])), ('bias', tensor([0.3618]))])
# tensor(0.0296, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5545])), ('bias', tensor([0.3613]))])
# tensor(0.0293, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5561])), ('bias', tensor([0.3603]))])
# tensor(0.0289, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5579])), ('bias', tensor([0.3598]))])
# tensor(0.0286, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5595])), ('bias', tensor([0.3588]))])
# tensor(0.0282, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5613])), ('bias', tensor([0.3583]))])
# tensor(0.0279, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5629])), ('bias', tensor([0.3573]))])
# tensor(0.0275, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5647])), ('bias', tensor([0.3568]))])
# tensor(0.0272, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5665])), ('bias', tensor([0.3563]))])
# tensor(0.0269, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5681])), ('bias', tensor([0.3553]))])
# tensor(0.0265, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5699])), ('bias', tensor([0.3548]))])
# tensor(0.0262, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5715])), ('bias', tensor([0.3538]))])
# tensor(0.0258, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5733])), ('bias', tensor([0.3533]))])
# tensor(0.0255, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5748])), ('bias', tensor([0.3523]))])
# tensor(0.0251, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5766])), ('bias', tensor([0.3518]))])
# tensor(0.0248, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5784])), ('bias', tensor([0.3513]))])
# /home/aj/miniconda3/envs/genai/lib/python3.10/site-packages/torch/autograd/graph.py:841: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass

# %% [markdown]
# #### step4: make predictions

# %%
# before moving to accuracy lets see if there is any effect on predicted values
# Let's predict with this half-trained model
with torch.inference_mode():
    y_preds_new = model0(x_test)

# %% [markdown]
# #### step5: visualize performance

# %%
plt.scatter(x_train,y_train, c='b', s=10, label=' Train Data')
plt.scatter(x_test,y_test, c='g', s=10, label=' Test Data')
plt.scatter(x_test.numpy(),y_preds_simple_mode.detach(), c='black', s=15, label=' Predictions by simple mode')
plt.scatter(x_test,y_preds_new, c='r', s=10, label=' Predictions with 10 epoch of training')
plt.legend(   frameon=True, title="Legend", fontsize=8,)

# %%
# with 50 epochs
with torch.inference_mode():
    y_preds_new_100 = model0(x_test) # by mistake put 100 here, I tried with 50 epochs only.

# %%
plt.scatter(x_train,y_train, c='b', s=10, label=' Train Data')
plt.scatter(x_test,y_test, c='g', s=10, label=' Test Data')
plt.scatter(x_test.numpy(),y_preds_simple_mode.detach(), c='black', s=15, label=' Predictions by simple mode')
plt.scatter(x_test,y_preds_new, c='r', s=10, label=' Predictions with 10 epoch of training')
plt.scatter(x_test,y_preds_new_100, c='pink', s=10, label=' Predictions with 50 epoch of training')
plt.legend(   frameon=True, title="Legend", fontsize=8,)

# %%
# with 50 epochs
with torch.inference_mode():
    y_preds_new_100_actual = model0(x_test)

# %%
plt.scatter(x_train,y_train, c='b', s=10, label=' Train Data')
plt.scatter(x_test,y_test, c='g', s=10, label=' Test Data')
plt.scatter(x_test.numpy(),y_preds_simple_mode.detach(), c='black', s=15, label=' Predictions by simple mode')
plt.scatter(x_test,y_preds_new, c='r', s=10, label=' Predictions with 10 epoch of training')
plt.scatter(x_test,y_preds_new_100, c='pink', s=10, label=' Predictions with 50 epoch of training')
plt.scatter(x_test,y_preds_new_100_actual, c='magenta', s=10, label=' Predictions with 100 epoch of training')
plt.legend(   frameon=True, title="Legend", fontsize=8,)

# %% [markdown]
# # To fully monitor the inside of training loop make following tweaks

# %%
epoch = []
training_loss = []
testing_loss = []

# training loop
for epoch in range(epoches):
    # 0. TRAINING | PUT MODEL IN TRAINING MODE
    model0.train() 
    
    # 1. Setup forward pass | FORWARD PASS TRAINING DATA USING FORWARD() METHOD INSIDE MODEL OBJECT
    y_pred_learned = model0(x_train)
    
    # 2. Calculate the loss values | only calculations, nothing more | TRAINING LOSS
    loss = loss_fn(y_pred_learned, y_train) # input first target next
    print(loss)
    training_loss.append(loss)
    
    # 3. Optimizer zero grad | Prevents Gradient Accumulation after each loop & Memory Management
    optimizer_fn.zero_grad()
    
    # 4. Perform back propagation w.r.t paramaeters of the model
    loss.backward() # compute gradient of every parameter with require_grad = true | check minima(convergence point) is achieved or not
    
    # 5. Setup Optimizer | make a calculation of how to change the parameters w.r.t back propagation of loss
    optimizer_fn.step() # by default, how the optimizer changes(values) will accumulate through the loop, so we have to zero them above via step 3.

    # TESTING/Evaluation | loop can be put under running conditions like run after every 10 epoch. 
    # model0.eval()  # turn off different settings not needed in testing  mode, like gradient tracking, dropout, and batch normalization
    # with torch.inference_mode():
    #     y_preds_100 = model0(x_test)
    #     loss can be calculated here | and that will be called TESTING LOSS
    # print statements to be printed after each epoch
    # testing_loss.append(loss)

    print(f"\n actual weight and bias must be: {weight,bias} \n randomly initialized weight and bias are: 0.3367,0.1288 \n weights and biases after {epoches} are {model0.state_dict()}")
# Out:
# tensor(0.0245, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5800])), ('bias', tensor([0.3503]))])
# tensor(0.0241, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5818])), ('bias', tensor([0.3498]))])
# tensor(0.0238, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5834])), ('bias', tensor([0.3488]))])
# tensor(0.0234, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5852])), ('bias', tensor([0.3483]))])
# tensor(0.0231, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5868])), ('bias', tensor([0.3473]))])
# tensor(0.0227, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5886])), ('bias', tensor([0.3468]))])
# tensor(0.0224, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5902])), ('bias', tensor([0.3458]))])
# tensor(0.0221, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5920])), ('bias', tensor([0.3453]))])
# tensor(0.0217, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5938])), ('bias', tensor([0.3448]))])
# tensor(0.0214, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5954])), ('bias', tensor([0.3438]))])
# tensor(0.0210, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5972])), ('bias', tensor([0.3433]))])
# tensor(0.0207, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.5988])), ('bias', tensor([0.3423]))])
# tensor(0.0203, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6006])), ('bias', tensor([0.3418]))])
# tensor(0.0200, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6022])), ('bias', tensor([0.3408]))])
# tensor(0.0196, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6040])), ('bias', tensor([0.3403]))])
# tensor(0.0193, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6058])), ('bias', tensor([0.3398]))])
# tensor(0.0190, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6074])), ('bias', tensor([0.3388]))])
# tensor(0.0186, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6092])), ('bias', tensor([0.3383]))])
# tensor(0.0183, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6108])), ('bias', tensor([0.3373]))])
# tensor(0.0179, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6126])), ('bias', tensor([0.3368]))])
# tensor(0.0176, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6141])), ('bias', tensor([0.3358]))])
# tensor(0.0172, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6159])), ('bias', tensor([0.3353]))])
# tensor(0.0169, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6175])), ('bias', tensor([0.3343]))])
# tensor(0.0166, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6193])), ('bias', tensor([0.3338]))])
# tensor(0.0162, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6211])), ('bias', tensor([0.3333]))])
# tensor(0.0159, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6227])), ('bias', tensor([0.3323]))])
# tensor(0.0155, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6245])), ('bias', tensor([0.3318]))])
# tensor(0.0152, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6261])), ('bias', tensor([0.3308]))])
# tensor(0.0148, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6279])), ('bias', tensor([0.3303]))])
# tensor(0.0145, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6295])), ('bias', tensor([0.3293]))])
# tensor(0.0142, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6313])), ('bias', tensor([0.3288]))])
# tensor(0.0138, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6331])), ('bias', tensor([0.3283]))])
# tensor(0.0135, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6347])), ('bias', tensor([0.3273]))])
# tensor(0.0131, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6365])), ('bias', tensor([0.3268]))])
# tensor(0.0128, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6381])), ('bias', tensor([0.3258]))])
# tensor(0.0124, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6399])), ('bias', tensor([0.3253]))])
# tensor(0.0121, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6415])), ('bias', tensor([0.3243]))])
# tensor(0.0118, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6433])), ('bias', tensor([0.3238]))])
# tensor(0.0114, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6451])), ('bias', tensor([0.3233]))])
# tensor(0.0111, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6467])), ('bias', tensor([0.3223]))])
# tensor(0.0107, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6485])), ('bias', tensor([0.3218]))])
# tensor(0.0104, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6501])), ('bias', tensor([0.3208]))])
# tensor(0.0100, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6519])), ('bias', tensor([0.3203]))])
# tensor(0.0097, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6534])), ('bias', tensor([0.3193]))])
# tensor(0.0093, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6552])), ('bias', tensor([0.3188]))])
# tensor(0.0090, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6568])), ('bias', tensor([0.3178]))])
# tensor(0.0087, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6586])), ('bias', tensor([0.3173]))])
# tensor(0.0083, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6604])), ('bias', tensor([0.3168]))])
# tensor(0.0080, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6620])), ('bias', tensor([0.3158]))])
# tensor(0.0076, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6638])), ('bias', tensor([0.3153]))])
# tensor(0.0073, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6654])), ('bias', tensor([0.3143]))])
# tensor(0.0069, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6672])), ('bias', tensor([0.3138]))])
# tensor(0.0066, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6688])), ('bias', tensor([0.3128]))])
# tensor(0.0063, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6706])), ('bias', tensor([0.3123]))])
# tensor(0.0059, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6724])), ('bias', tensor([0.3118]))])
# tensor(0.0056, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6740])), ('bias', tensor([0.3108]))])
# tensor(0.0052, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6758])), ('bias', tensor([0.3103]))])
# tensor(0.0049, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6774])), ('bias', tensor([0.3093]))])
# tensor(0.0045, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6792])), ('bias', tensor([0.3088]))])
# tensor(0.0042, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6808])), ('bias', tensor([0.3078]))])
# tensor(0.0039, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6826])), ('bias', tensor([0.3073]))])
# tensor(0.0035, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6844])), ('bias', tensor([0.3068]))])
# tensor(0.0032, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6860])), ('bias', tensor([0.3058]))])
# tensor(0.0028, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6878])), ('bias', tensor([0.3053]))])
# tensor(0.0025, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6894])), ('bias', tensor([0.3043]))])
# tensor(0.0021, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6912])), ('bias', tensor([0.3038]))])
# tensor(0.0018, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6927])), ('bias', tensor([0.3028]))])
# tensor(0.0015, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6947])), ('bias', tensor([0.3028]))])
# tensor(0.0012, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])
# tensor(0.0089, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6951])), ('bias', tensor([0.2993]))])
# tensor(0.0026, grad_fn=<MeanBackward0>)
#
#  actual weight and bias must be: (0.7, 0.3)
#  randomly initialized weight and bias are: 0.3367,0.1288
#  weights and biases after 100 are OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])

# %% [markdown]
# # now make graph from above mentioned lists to check what happened in which iteration

# %%
# make graph of train loss and test loss using plt.plot

# %% [markdown]
# #### step6: save model

# %%
from pathlib import Path
current_path = Path.cwd()
dir_path = current_path / 'Data' / 'models'
dir_path
# Out:
# PosixPath('/home/aj/GenAI/deep_learning/CNN/Data/models')

# %%
model_path = dir_path / 'model0_state_dict.pth'
torch.save(obj=model0.state_dict(), f=model_path)
